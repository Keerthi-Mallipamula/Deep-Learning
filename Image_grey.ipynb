# %%
import matplotlib.pyplot as plt

# %%
import cv2

# %%
img = cv2.imread(r"C:\Users\user\Downloads\Fruits.jpg")

# %%
img
# Out:
# array([[[255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255],
#         ...,
#         [255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255]],
#
#        [[255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255],
#         ...,
#         [255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255]],
#
#        [[255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255],
#         ...,
#         [255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255]],
#
#        ...,
#
#        [[255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255],
#         ...,
#         [255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255]],
#
#        [[255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255],
#         ...,
#         [255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255]],
#
#        [[255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255],
# ...

# %%
img.shape
# Out:
# (420, 600, 3)

# %%
plt.imshow(img)

# %%
cv2.imshow("Fruits", img)
cv2.waitKey(0)
# Out:
# -1

# %%
img_gray = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)

# %%
plt.imshow(img_gray)

# %%
img.shape
# Out:
# (420, 600, 3)

# %%
img_gray.shape
# Out:
# (420, 600)

# %%
cv2.imshow("Fruit", img)
cv2.waitKey(-1)
# Out:
# -1

# %%
cv2.imshow("Fruit_Gray", img_gray)
cv2.waitKey(-1)
# Out:
# -1

# %%
cv2.imshow("Fruit", img)
cv2.imshow("Fruit_Gray", img_gray)
cv2.waitKey(-1)
# Out:
# -1

# %%
img.shape
# Out:
# (420, 600, 3)

# %%
img[ : , : , 0] = 0

# %%
cv2.imshow("Original", img1)
cv2.imshow("No Red", img)
cv2.waitKey(-1)
# Out:
# -1

# %%
img1 = cv2.imread(r"C:\Users\user\Downloads\Fruits.jpg")

# %%
img2 = img1.copy()

# %%
img2[ : , : , 1] = 0

# %%
cv2.imshow("Original", img1)
cv2.imshow("No Red", img)
cv2.imshow("No Green", img2)
cv2.waitKey(-1)
# Out:
# -1

# %%
img3 = img1.copy()

# %%
img3[ : , : , 2] = 0

# %%
cv2.imshow("No Blue", img3)
cv2.waitKey(-1)
# Out:
# -1

# %%
cv2.imshow("Original", img1)
cv2.imshow("No Red", img)
cv2.imshow("No Green", img2)
cv2.imshow("No Blue", img3)
cv2.waitKey(-1)
# Out:
# -1
