# %%
import matplotlib.pyplot as plt

# %%
import cv2

# %%
img = cv2.imread(r"C:\Users\user\Downloads\Fruits.jpg")

# %%
img
# Out:
# array([[[255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255],
#         ...,
#         [255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255]],
#
#        [[255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255],
#         ...,
#         [255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255]],
#
#        [[255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255],
#         ...,
#         [255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255]],
#
#        ...,
#
#        [[255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255],
#         ...,
#         [255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255]],
#
#        [[255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255],
#         ...,
#         [255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255]],
#
#        [[255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255],
# ...

# %%
cv2.imshow("Fruit_Image", img)
cv2.waitKey(-1)
# Out:
# -1

# %%
img.shape
# Out:
# (420, 600, 3)

# %%
plt.imshow(img)

# %%
horse = cv2.imread(r"C:\Users\user\Downloads\Horse.jpg")

# %%
horse
# Out:
# array([[[49, 56, 41],
#         [49, 56, 41],
#         [49, 56, 41],
#         ...,
#         [49, 56, 41],
#         [49, 56, 41],
#         [49, 56, 41]],
#
#        [[49, 56, 41],
#         [49, 56, 41],
#         [49, 56, 41],
#         ...,
#         [49, 56, 41],
#         [49, 56, 41],
#         [49, 56, 41]],
#
#        [[49, 56, 41],
#         [49, 56, 41],
#         [49, 56, 41],
#         ...,
#         [49, 56, 41],
#         [49, 56, 41],
#         [49, 56, 41]],
#
#        ...,
#
#        [[49, 56, 41],
#         [49, 56, 41],
#         [49, 56, 41],
#         ...,
#         [49, 56, 41],
#         [49, 56, 41],
#         [49, 56, 41]],
#
#        [[49, 56, 41],
#         [49, 56, 41],
#         [49, 56, 41],
#         ...,
#         [49, 56, 41],
#         [49, 56, 41],
#         [49, 56, 41]],
#
#        [[49, 56, 41],
#         [49, 56, 41],
#         [49, 56, 41],
#         ...,
#         [49, 56, 41],
#         [49, 56, 41],
#         [49, 56, 41]]], dtype=uint8)

# %%
horse.shape
# Out:
# (1308, 736, 3)

# %%
cv2.imshow("Horse Image", horse)
cv2.waitKey(0)
# Out:
# -1

# %%
cv2.imshow("Fruit", img)
cv2.waitKey(-1)
# Out:
# -1
