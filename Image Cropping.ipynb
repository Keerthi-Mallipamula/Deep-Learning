# %%
import cv2

# %%
import matplotlib.pyplot as plt

# %%
horse = cv2.imread(r"C:\Users\user\Downloads\Horse.jpg")

# %%
horse
# Out:
# array([[[49, 56, 41],
#         [49, 56, 41],
#         [49, 56, 41],
#         ...,
#         [49, 56, 41],
#         [49, 56, 41],
#         [49, 56, 41]],
#
#        [[49, 56, 41],
#         [49, 56, 41],
#         [49, 56, 41],
#         ...,
#         [49, 56, 41],
#         [49, 56, 41],
#         [49, 56, 41]],
#
#        [[49, 56, 41],
#         [49, 56, 41],
#         [49, 56, 41],
#         ...,
#         [49, 56, 41],
#         [49, 56, 41],
#         [49, 56, 41]],
#
#        ...,
#
#        [[49, 56, 41],
#         [49, 56, 41],
#         [49, 56, 41],
#         ...,
#         [49, 56, 41],
#         [49, 56, 41],
#         [49, 56, 41]],
#
#        [[49, 56, 41],
#         [49, 56, 41],
#         [49, 56, 41],
#         ...,
#         [49, 56, 41],
#         [49, 56, 41],
#         [49, 56, 41]],
#
#        [[49, 56, 41],
#         [49, 56, 41],
#         [49, 56, 41],
#         ...,
#         [49, 56, 41],
#         [49, 56, 41],
#         [49, 56, 41]]], dtype=uint8)

# %%
horse.shape
# Out:
# (1308, 736, 3)

# %%
cv2.imshow("Horse Image", horse)
cv2.waitKey(-1)
# Out:
# -1

# %%
img1 = horse[ 300 : 600 , 100 : 350]

# %%
cv2.imshow("Horse Image", horse)
cv2.imshow("Horse Head", img1)
cv2.waitKey(-1)
# Out:
# -1
